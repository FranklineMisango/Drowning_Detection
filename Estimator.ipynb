# %%
import uuid   # Unique identifier
import os
import time
import cv2
import torch

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15637, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (144/144), done.
# remote: Total 15637 (delta 123), reused 171 (delta 100), pack-reused 15393
# Receiving objects: 100% (15637/15637), 14.58 MiB | 4.60 MiB/s, done.
# Resolving deltas: 100% (10652/10652), done.

# %%
# !cd yolov5 & pip install -r '/home/misango/code/Drowning_Detection/yolov5/requirements.txt'
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
from ultralytics import YOLO

# %%
import os
import cv2
import uuid

IMAGES_PATH = os.path.join(os.getcwd(), 'Datapool')
labels = ['Safe', 'Drowning']
number_imgs = 50

# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # load image from directory
        img_folder = os.path.join(IMAGES_PATH, label)
        img_file = os.listdir(img_folder)[img_num]
        img_path = os.path.join(img_folder, img_file)
        img = cv2.imread(img_path)
        
        # Render to the screen
        cv2.imshow('Image Collection', img)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cv2.destroyAllWindows()

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1())+'.jpg'))
# Out:
# /home/misango/code/Drowning_Detection/Datapool/Safe.e2b7e9ee-e9c7-11ed-801c-131efd4fecac.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(number_imgs):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# /home/misango/code/Drowning_Detection/Datapool/Safe.a5c27d4d-e9c7-11ed-801c-131efd4fecac.jpg
# ...
# /home/misango/code/Drowning_Detection/Datapool/Safe.a5c27d4e-e9c7-11ed-801c-131efd4fecac.jpg
# ...
# /home/misango/code/Drowning_Detection/Datapool/Safe.a5c27d4f-e9c7-11ed-801c-131efd4fecac.jpg
# ...
# /home/misango/code/Drowning_Detection/Datapool/Safe.a5c27d50-e9c7-11ed-801c-131efd4fecac.jpg
# ...
# /home/misango/code/Drowning_Detection/Datapool/Safe.a5c27d51-e9c7-11ed-801c-131efd4fecac.jpg
# ...
# /home/misango/code/Drowning_Detection/Datapool/Safe.a5c27d52-e9c7-11ed-801c-131efd4fecac.jpg
# ...
# /home/misango/code/Drowning_Detection/Datapool/Safe.a5c27d53-e9c7-11ed-801c-131efd4fecac.jpg
# ...
# /home/misango/code/Drowning_Detection/Datapool/Safe.a5c27d54-e9c7-11ed-801c-131efd4fecac.jpg
# ...
# /home/misango/code/Drowning_Detection/Datapool/Safe.a5c27d55-e9c7-11ed-801c-131efd4fecac.jpg
# ...
# /home/misango/code/Drowning_Detection/Datapool/Safe.a5c27d56-e9c7-11ed-801c-131efd4fecac.jpg
# ...

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8n.pt')

# %%
# !mkdir datasets
# %cd datasets
from roboflow import Roboflow
rf = Roboflow(api_key="Dnpd4PGIz0Yu8Y5lBgup")
project = rf.workspace("franklines-space-ywbil").project("drowning-detection-vxucl")
dataset = project.version(1).download("yolov8")
# Out:
# /home/misango/code/Drowning_Detection/datasets
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.91, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to Drowning-Detection-1 in yolov8:: 100%|██████████| 228/228 [00:00<00:00, 5282.97it/s]

# %%
# %cd ..
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /home/misango/code/Drowning_Detection
# Ultralytics YOLOv8.0.91 🚀 Python-3.10.6 torch-2.0.0+cu117 CPU
# ...

# %%
# !ls /home/misango/code/Drowning_Detection/runs/detect/train3
# Out:
# args.yaml
# confusion_matrix.png
# events.out.tfevents.1683132786.misango-OptiPlex-7020.38905.0
# F1_curve.png
# labels_correlogram.jpg
# labels.jpg
# P_curve.png
# PR_curve.png
# R_curve.png
# results.csv
# results.png
# train_batch0.jpg
# train_batch1.jpg
# train_batch2.jpg
# val_batch0_labels.jpg
# val_batch0_pred.jpg
# weights

# %%
# !yolo task=detect mode=val model= /home/misango/code/Drowning_Detection/runs/detect/train3/weights/best.pt data={dataset.location}/data.yaml
# Out:
# Ultralytics YOLOv8.0.91 🚀 Python-3.10.6 torch-2.0.0+cu117 CPU
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /home/misango/code/Drowning_Detection/datasets/Drowning-Detection-
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         20         20      0.883      0.917      0.941      0.734
#               Drowning         20         12      0.996      0.833      0.959      0.791
#                   Safe         20          8       0.77          1      0.923      0.677
# Speed: 4.6ms preprocess, 598.8ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/val

# %%
# !yolo task=detect mode=predict model=/home/misango/code/Drowning_Detection/runs/detect/train3/weights/best.pt conf=0.25 source={dataset.location}/test/images
# Out:
# Ultralytics YOLOv8.0.91 🚀 Python-3.10.6 torch-2.0.0+cu117 CPU
# Model summary (fused): 168 layers, 11126358 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/13 /home/misango/code/Drowning_Detection/datasets/Drowning-Detection-1/test/images/frame_0120_png.rf.a7fd45c4032a8daee1f199e9b7e52139.jpg: 800x800 1 Safe, 1066.7ms
# image 2/13 /home/misango/code/Drowning_Detection/datasets/Drowning-Detection-1/test/images/frame_0138_png.rf.036549d87dd6a7bdc09d5a1d547163dc.jpg: 800x800 1 Safe, 838.7ms
# image 3/13 /home/misango/code/Drowning_Detection/datasets/Drowning-Detection-1/test/images/frame_0147_png.rf.1976d5509c1faa6c25aba69c8c928a32.jpg: 800x800 1 Safe, 1017.2ms
# image 4/13 /home/misango/code/Drowning_Detection/datasets/Drowning-Detection-1/test/images/frame_0148_png.rf.d804acee1808c2d90aa4b50a484bf1c9.jpg: 800x800 1 Safe, 867.2ms
# ...

# %%
project.version(1).deploy(model_type="yolov8", model_path=f"/home/misango/code/Drowning_Detection/runs/detect/train3/")
# Out:
# Dependency ultralytics<=8.0.20 is required but found version=8.0.91, to fix: `pip install ultralytics<=8.0.20`
# An error occured when getting the model upload URL: This version already has a trained model. Please generate and train a new version in order to upload model to Roboflow.
